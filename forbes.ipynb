# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import cumfreq

# %%
df = pd.read_table("https://raw.githubusercontent.com/tnn1t1s/notebooks/master/data/forbes/400.tsv")
df['net'].describe()
df
# Out:
#       id                      name    net  age                    home  \
# 0      1                Bill Gates  76.00   60              Medina, WA
# 1      2            Warren Buffett  62.00   85               Omaha  NE
# 2      3             Larry Ellison  47.50   71            Woodside  CA
# 3      4                Jeff Bezos  47.00   51             Seattle  WA
# 4      5              Charles Koch  41.00   80             Wichita  KS
# 5      5                David Koch  41.00   75            New York  NY
# 6      7           Mark Zuckerberg  40.30   31           Palo Alto  CA
# 7      8         Michael Bloomberg  38.60   73            New York  NY
# 8      9                Jim Walton  33.70   67         Bentonville  AR
# 9     10                Larry Page  33.30   42           Palo Alto  CA
# 10    11               Sergey Brin  32.60   42           Los Altos  CA
# 11    12              Alice Walton  32.00   66          Fort Worth  TX
# ...

# %%
data = df['net']
# sort the data:
data_sorted = np.sort(data)

# calculate the proportional values of samples
p = 1.0 * arange(len(data)) / (len(data) - 1)

# plot the sorted data:
fig = figure()
ax1 = fig.add_subplot(121)
ax1.plot(p, data_sorted)
ax1.set_xlabel('$p$')
ax1.set_ylabel('$x$')

ax2 = fig.add_subplot(122)
ax2.plot(data_sorted, p)
ax2.set_xlabel('$x$')
ax2.set_ylabel('$p$')

# %%
df2 = df[['net','age','industry']]
g = df2.groupby(['industry'])
g.mean().sort('net',ascending=[False])
g.count().sort('net', ascending=[False])
# Out:
#                           net  age
# industry
# hedgefund                  29   29
# investments                22   22
# real estate                20   20
# private equity             16   16
# hotels  investments        10   10
# cleaning products           8    8
# pipelines                   7    7
# money management            7    7
# pharmaceuticals             7    7
# Wal-Mart                    6    6
# media                       6    6
# Cargill                     6    6
# venture capital             5    5
# medical equipment           5    5
# oil  investments            5    5
# software                    4    4
# cable television            4    4
# diversified                 4    4
# retail                      4    4
# Google                      3    3
# business software           3    3
# candy                       3    3
# Airbnb                      3    3
# beer                        3    3
# eBay                        3    3
# ...
